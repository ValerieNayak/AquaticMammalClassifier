# %% [markdown]
# # More Aquatic Mammals
# Valerie Nayak <br>
# Building my own dataset to categorize sea otters, sea lions, harbor seals, and manatees.

# %%
import sys,os
from pathlib import Path

from fastai import *
from fastai.vision import *

# %%
  # !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
folder = 'sea_lions'
file = 'urls_sealions.csv'

path = Path('data/sea_mammals')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

path.ls()
# Out:
# [PosixPath('data/sea_mammals/sea_lions'),
#  PosixPath('data/sea_mammals/sea_otters')]

# %%
folder = 'sea_otters'
file = 'urls_seaotters.csv'

path = Path('data/sea_mammals')
dest = path/folderpath.ls()
dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download your images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename as well as the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
classes = ['sea_otters','sea_lions', 'harbor_seals', 'manatees']

# %%
os.getcwd()
# Out:
# '/content'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-07bdf23f-4579-48e7-aec1-d1c0c8e3e9a9" name="files[]" multiple disabled />
#      <output id="result-07bdf23f-4579-48e7-aec1-d1c0c8e3e9a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_harborseals.csv to urls_harborseals.csv
# Saving urls_manatees.csv to urls_manatees.csv

# %%
os.mkdir('./data2')

# %%
os.getcwd()
os.listdir()

# os.rename("./urls_seaotters.csv", "./data/urls_seaotters.csv")
# os.rename("./urls_sealions.csv", "./data/urls_sealions.csv")

os.rename("./urls_harborseals.csv", "./data2/urls_harborseals.csv")
os.rename("./urls_manatees.csv", "./data2/urls_manatees.csv")

# %%
os.rmdir('./data/sea_lions')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-b4f8741c61a7> in <module>()
# ----> 1 os.rmdir('./data/sea_lions')
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/sea_lions'

# %%
os.listdir('data2')
# Out:
# ['urls_manatees.csv',
#  'urls_harborseals.csv',
#  'urls_seaotters.csv',
#  'sea_lions',
#  'models',
#  'urls_sealions.csv',
#  'sea_otters']

# %%
folder = 'sea_lions'
file = 'urls_sealions.csv'

path = Path('./data2')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

print('dest', dest)

path.ls()

download_images(path/file, dest, max_pics=200)
# Out:
# dest data2/sea_lions
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:18<00:00]
#     </div>
# Error https://www.indianz.com/News/2018/08/16/sealioncolumbiariver.jpg ('Connection aborted.', OSError(0, 'Error'))
# ...

# %%
print(folder)
# Out:
# sea_lions

# %%
os.listdir('data2')
# Out:
# ['urls_seaotters.csv', 'sea_lions', 'urls_sealions.csv']

# %%
os.listdir('./data/sea_lions')
# Out:
# ['00000025.jpg',
#  '00000138.jpg',
#  '00000111.jpg',
#  '00000145.jpg',
#  '00000026.jpg',
#  '00000180.jpg',
#  '00000135.jpg',
#  '00000102.jpg',
#  '00000073.jpg',
#  '00000019.jpg',
#  '00000002.jpg',
#  '00000021.aspx',
#  '00000186.jpg',
#  '00000179.jpg',
#  '00000067.jpg',
#  '00000049.jpg',
#  '00000075.jpg',
#  '00000040.jpg',
#  '00000106.jpg',
#  '00000090.jpg',
#  '00000096.jpg',
#  '00000117.jpg',
#  '00000133.jpg',
#  '00000050.jpg',
#  '00000041.jpg',
#  '00000009.jpg',
#  '00000100.jpg',
#  '00000013.jpg',
#  '00000116.jpg',
#  '00000147.jpg',
#  '00000139.jpg',
#  '00000150.jpg',
#  '00000028.png',
#  '00000172.jpg',
#  '00000007.jpg',
#  '00000005.jpg',
#  '00000010.jpg',
#  '00000163.jpg',
#  '00000099.jpg',
#  '00000053.jpg',
#  '00000036.jpg',
#  '00000114.jpg',
#  '00000171.jpg',
#  '00000083.jpg',
#  '00000094.jpg',
#  '00000078.jpg',
#  '00000085.jpg',
#  '00000087.jpg',
#  '00000051.jpg',
#  '00000120.jpg',
#  '00000185.jpg',
#  '00000095.jpg',
# ...

# %%
for item in os.listdir('data'):
    if not item.endswith(".csv"):
        os.remove('./data/'+item)

# %%
folder = 'sea_otters'
file = 'urls_seaotters.csv'

path = Path('./data2')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

print('dest', dest)

path.ls()

download_images(path/file, dest, max_pics=200)
# Out:
# dest data2/sea_otters
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:21<00:00]
#     </div>
# Error https://www.washingtonpost.com/resizer/uDaBgUqVmYhjjt3Qi0IE15YeYr8=/1484x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/OWVMMVS2CUI6RBMPCK7MWTLAM4.jpg HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)

# %%
folder = 'harbor_seals'
file = 'urls_harborseals.csv'

path = Path('./data2')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

print('dest', dest)

path.ls()

download_images(path/file, dest, max_pics=200)

# %%
folder = 'manatees'
file = 'urls_manatees.csv'

path = Path('./data2')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

print('dest', dest)

path.ls()

download_images(path/file, dest, max_pics=200)

# %%
os.listdir('data2')
# Out:
# ['urls_manatees.csv',
#  'urls_harborseals.csv',
#  'urls_seaotters.csv',
#  'sea_lions',
#  'models',
#  'urls_sealions.csv',
#  'manatees',
#  'harbor_seals',
#  'sea_otters']

# %%
os.listdir('./data/sea_otters')
# Out:
# ['00000025.jpg',
#  '00000138.jpg',
#  '00000111.jpg',
#  '00000145.jpg',
#  '00000180.jpg',
#  '00000135.jpg',
#  '00000134.jpg',
#  '00000102.jpg',
#  '00000073.jpg',
#  '00000002.jpg',
#  '00000186.jpg',
#  '00000179.jpg',
#  '00000067.jpg',
#  '00000049.jpg',
#  '00000075.jpg',
#  '00000040.jpg',
#  '00000106.jpg',
#  '00000090.jpg',
#  '00000096.jpg',
#  '00000117.jpg',
#  '00000133.jpg',
#  '00000030.jpg',
#  '00000105.jpg',
#  '00000041.jpg',
#  '00000009.jpg',
#  '00000100.jpg',
#  '00000013.jpg',
#  '00000116.jpg',
#  '00000147.jpg',
#  '00000139.jpg',
#  '00000150.jpg',
#  '00000172.jpg',
#  '00000005.jpg',
#  '00000010.jpg',
#  '00000163.jpg',
#  '00000099.jpg',
#  '00000026.png',
#  '00000036.jpg',
#  '00000114.jpg',
#  '00000171.jpg',
#  '00000083.jpg',
#  '00000094.jpg',
#  '00000078.jpg',
#  '00000087.jpg',
#  '00000120.jpg',
#  '00000185.jpg',
#  '00000095.jpg',
#  '00000187.jpg',
#  '00000146.jpg',
#  '00000014.jpg',
#  '00000003.jpg',
#  '00000151.jpg',
# ...

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)

# %% [markdown]
# ### View Data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['harbor_seals', 'manatees', 'sea_lions', 'sea_otters']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['harbor_seals', 'manatees', 'sea_lions', 'sea_otters'], 4, 594, 148)

# %% [markdown]
# ## Train Model

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.199852</td>
#       <td>0.398842</td>
#       <td>0.141892</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.687478</td>
#       <td>0.214403</td>
#       <td>0.067568</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.466682</td>
#       <td>0.179312</td>
#       <td>0.067568</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.375964</td>
#       <td>0.177010</td>
#       <td>0.067568</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(4, max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.155256</td>
#       <td>0.161643</td>
#       <td>0.067568</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.125632</td>
#       <td>0.148448</td>
#       <td>0.047297</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.104253</td>
#       <td>0.122382</td>
#       <td>0.033784</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.084231</td>
#       <td>0.123796</td>
#       <td>0.033784</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ### Analysis

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# ## Summary
# This is a modification of my first sea mammals lab. I classified sea otters, sea lions, harbor seals, and manatees with around a 3% error rate. This does a pretty good job! :)
